# %%
import numpy as np
from os.path import join
from pathlib import Path
from matresdev.db.simdb.simdb import simdb
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D
import numpy as np
import scipy as sp
import pandas as pd
import csv

# %%
home = str(Path.home())
folder = join(home,
            'jupyter',
             'schubtal')
fname = join(folder, 'schubtaltex.csv')
data = pd.read_csv(fname, delimiter=';', decimal=',', header=None)

# %%
fig = plt.figure()
ax1 = fig.add_subplot(111, projection='3d')

rho = data[0]
lam = data[1]
ratio = data[2]
#ax1.plot(rho,lam,ratio)
ax1.scatter(lam,rho,ratio, c='b', s=3, marker='o')
#ax1.plot_trisurf(lam,rho,ratio,cmap='viridis', edgecolor='none');

ax1.set_xlabel('lambda')
ax1.set_ylabel('rho')
ax1.set_zlabel('MuV / MRd')

plt.show()
