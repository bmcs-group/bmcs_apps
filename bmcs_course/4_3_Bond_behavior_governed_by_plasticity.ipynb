# %% [markdown]
# # 4.3 Bond behavior governed by plasticity
# Define a bond-slip law governed by plasticity and loading history using unloading.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
from bmcs.bond_slip import BondSlipModel

# %% [markdown]
# ## Isotropic hardening

# %% [markdown]
# ### Construct an instance of bond-slip model and display its state

# %%
bs1 = BondSlipModel(mats_eval_type = 'elasto-plasticity')
bs1 # display the state of bond-slip model
# Out:
#         \begin{array}{lrrl}\hline
#         \textrm{k_max} & k_{\max} = 400 & \textrm{[-]} & \textrm{maximum number of iterations}  \\
#                 \textrm{tolerance} & \epsilon = 0.0001 & \textrm{[-]} & \textrm{required accuracy}  \\
#                 \textrm{n_e_x} & n_\mathrm{E} = 1 & \textrm{[-]} & \textrm{number of finite elements along the embedded length}  \\
#                 \textrm{mats_eval_type} & \textrm{elasto-plasticity} & & \textrm{material model type}  \\
#                 \textrm{control_variable} & \textrm{u} & & \textrm{displacement or force control: [u|f]}  \\
#                 \textrm{w_max} & w_{\max} = 1.0 & \textrm{[mm]} & \textrm{maximum pullout slip}  \\
#                 \textrm{fixed_boundary} & \textrm{non-loaded end (matrix)} & & \textrm{which side of the specimen is fixed [non-loaded end [matrix], loaded end [matrix], non-loaded end [reinf]]}  \\
#                 \hline
#         \textbf{loading_scenario} & \textrm{LoadingScenario} & & \textrm{object defining the loading scenario} \\
#             \textbf{cross_section} & \textrm{CrossSection} & & \textrm{cross section parameters} \\
#             \textbf{geometry} & \textrm{Geometry} & & \textrm{geometry parameters of the boundary value problem} \\
#             \textbf{mats_eval} & \textrm{MATSBondSlipEP} & & \textrm{material model of the interface} \\
#             \hline
#         \end{array}

# %% [markdown]
# ### Define the parameters of the material model

# %%
bs1.mats_eval.trait_set(E_b = 20000.0,
                        K = 500.0,
                        gamma = 0.0,
                        tau_bar = 5.0)
bs1.mats_eval # display the values of material model parameters
# Out:
#         \begin{array}{lrrl}\hline
#         \textrm{E_m} & E_\mathrm{m} = 30000.0 & \textrm{[MPa]} & \textrm{Stiffness of the matrix}  \\
#                 \textrm{E_f} & E_\mathrm{f} = 200000.0 & \textrm{[MPa]} & \textrm{Stiffness of the reinforcement}  \\
#                 \textrm{E_b} & E_\mathrm{b} = 20000.0 & \textrm{[MPa]} & \textrm{Bond stiffness}  \\
#                 \textrm{gamma} & \gamma = 0.0 & \textrm{[MPa]} & \textrm{Kinematic hardening modulus}  \\
#                 \textrm{K} & K = 500.0 & \textrm{[MPa]} & \textrm{Isotropic hardening modulus}  \\
#                 \textrm{tau_bar} & \bar{\tau} = 5.0 & \textrm{[None]} & \textrm{Reversibility limit}  \\
#                 \hline
#         \hline
#         \end{array}

# %% [markdown]
# ### Define the loading scenario
# In first stetp - set the type of the load and in the second step define its parameters.

# %%
bs1.loading_scenario.trait_set(loading_type='cyclic',
                               amplitude_type='increasing',
                               loading_range='symmetric',
                               )
bs1.loading_scenario.trait_set(number_of_cycles=3,
                               maximum_loading=0.005,
                              unloading_ratio =0.0)
# Out:
#         \begin{array}{lrrl}\hline
#         \textrm{loading_type} & option = cyclic & \textrm{[-]} & \textrm{possible values: [monotonic, cyclic]}  \\
#                 \textrm{number_of_cycles} & n_\mathrm{cycles} = 3 & \textrm{[-]} & \textrm{for cyclic loading}  \\
#                 \textrm{maximum_loading} & \phi_{\max} = 0.005 & \textrm{[-]} & \textrm{load factor at maximum load level}  \\
#                 \textrm{unloading_ratio} & \phi_{\mathrm{unload}} = 0.0 & \textrm{[-]} & \textrm{fraction of maximum load at lowest load level}  \\
#                 \textrm{number_of_increments} & n_{\mathrm{incr}} = 20 & \textrm{[-]} & \textrm{number of values within a monotonic load branch}  \\
#                 \textrm{amplitude_type} & option = increasing & \textrm{[-]} & \textrm{possible values: [increasing, constant]}  \\
#                 \textrm{loading_range} & option = symmetric & \textrm{[-]} & \textrm{possible values: [non-symmetric, symmetric]}  \\
#                 \hline
#         \hline
#         \end{array}

# %% [markdown]
# ### Display the load as a function of pseudo time

# %%
bs1.loading_scenario.plot(plt.axes())

# %% [markdown]
# ### Run the calculation

# %%
bs1.sim.run()

# %% [markdown]
# ### Access the results

# %%
ax = plt.axes()
ax.grid(True)
bs1.hist.plot_Pw(ax,1)

# %% [markdown]
# ## Kinematic hardening

# %%
bs2 = BondSlipModel(mats_eval_type = 'elasto-plasticity')
bs2.mats_eval.E_b = 20000.0
bs2.mats_eval.K = 0.0
bs2.mats_eval.gamma = -500.0
bs2.mats_eval.tau_bar = 5.0
bs2.mats_eval # check
# Out:
#         \begin{array}{lrrl}\hline
#         \textrm{E_m} & E_\mathrm{m} = 30000.0 & \textrm{[MPa]} & \textrm{Stiffness of the matrix}  \\
#                 \textrm{E_f} & E_\mathrm{f} = 200000.0 & \textrm{[MPa]} & \textrm{Stiffness of the reinforcement}  \\
#                 \textrm{E_b} & E_\mathrm{b} = 20000.0 & \textrm{[MPa]} & \textrm{Bond stiffness}  \\
#                 \textrm{gamma} & \gamma = -500.0 & \textrm{[MPa]} & \textrm{Kinematic hardening modulus}  \\
#                 \textrm{K} & K = 0.0 & \textrm{[MPa]} & \textrm{Isotropic hardening modulus}  \\
#                 \textrm{tau_bar} & \bar{\tau} = 5.0 & \textrm{[None]} & \textrm{Reversibility limit}  \\
#                 \hline
#         \hline
#         \end{array}

# %%
bs2.loading_scenario.trait_set(loading_type='cyclic',
                               amplitude_type='increasing',
                               loading_range='symmetric',
                               )
bs2.loading_scenario.trait_set(number_of_cycles=3,
                               maximum_loading=0.005,
                               unloading_ratio =0.0)
bs2.loading_scenario.plot(plt.axes()) # check
plt.grid()

# %%
bs2.sim.run()

# %%
ax = plt.axes()
ax.grid(True)
bs2.hist.plot_Pw(ax,1)
