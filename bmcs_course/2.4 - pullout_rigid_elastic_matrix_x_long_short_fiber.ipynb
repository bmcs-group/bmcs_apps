# %% [markdown]
# # Model comparison
# Let us now import the three models
#  - pullout of long fiber from long rigid matrix
#  - pullout of long fiber from short rigid matrix
#  - pullout of long fiber from long elastic matrix
#  - pullout of short fiber from long rigid matrix
#  - pullout of short clamped fiber from rigid matrix

# %%
# %%capture
# %run 2_1_pullout_from_rigid_matrix.ipynb

# %%
# %%capture
# %run 2_2_pullout_from_elastic_matrix.ipynb

# %%
# %%capture
# %run 2_3_pullout_short_fiber.ipynb

# %%
import bmcs_pullout_ui as poui

# %%
po = poui.ModelInteract(
    models=[PullOutFromElastic, PullOutFromRigid, PullOutShortFiber],
    py_vars=list(py_vars),
    map_py2sp=map_py2sp
)

# %%
po.interact_geometry()
# Out:
# <img src="data:image/png;base64,..." width="799.8">
# ...
